# %%
# Siempre que usemos matplotlib en Jupyter es necesario poner esta línea antes de cualquier otra
# %matplotlib inline

# Importamos las bibliotecas necesarias y les asigamos un alias
import skimage                           # Biblioteca para la manipulación de imágenes
import numpy as np                       # Biblioteca para la manipulación de matrices

# Importamos algunos paquetes específicos
from matplotlib import pyplot as plt     # Biblioteca para crear graficas y mostrar las imágenes en pantalla

from skimage import io                   # Paquete para lectura/escritura de imágenes
from skimage import color                # Paquete con las operaciones de transformaciones entre espacios de color
from skimage import exposure             # Paquete con las funciones para calcular y alterar el histograma
from skimage import filters              # Paquete que contiene las máscaras y filtros de suavizado y realzado
from skimage import util                 # Paquete que contiene las funciones para cambiar el tipo de dato 
                                         #de las imágenes
from scipy import ndimage                # Usamos esta biblioteca para realizar la operación de convolución
import skdemo
from skimage import morphology           # Para crear el kernel de convolución en los filtros no lienales
from skimage import transform            # Esta biblioteca es la que contiene la implementación de Hough
from skimage import measure              # Esta biblioteca contiene el método de etiquetado de regiones
from skimage import feature              # Esta biblioteca es la que contiene la implementación del cann

###########################

from scipy.stats import kde              # Esta biblioteca es necesaria para estimar la función de densidad de los datos
from sklearn import preprocessing        # Este paquete contiene las funciones de preprocesamiento de datos
from sklearn import feature_selection    # Este paquete contiene los métodos de selección de características de sklearn
from sklearn import svm                  # Este paquete contiene las funciones de un clasificador SVM
from sklearn import model_selection      # Este paquete contiene las funciones de particionamiento de datos y validación cruzada
from sklearn import metrics              # Este paquete contiene las funciones para evaluar un clasificador

from sklearn.linear_model import LinearRegression

# Con este nos aseguramos que las imagenes en niveles de gris, se vean como tal siempre.
plt.rcParams['image.cmap'] = 'gray'
plt.rcParams['image.interpolation'] = 'none'

# %%
#Cargamos conjunto de naranjas buenas
image_1 = io.imread("images/good/image1.jpeg")
image_2 = io.imread("images/good/image2.jpeg")
image_3 = io.imread("images/good/image3.jpeg")
image_4 = io.imread("images/good/image4.jpeg")
image_5 = io.imread("images/good/image5.jpeg")
image_6 = io.imread("images/good/image6.jpeg")
image_7 = io.imread("images/good/image7.jpeg")
image_8 = io.imread("images/good/image8.jpeg")
image_9 = io.imread("images/good/image9.jpeg")
image_10 = io.imread("images/good/image10.jpeg")
image_11 = io.imread("images/good/image11.jpeg")
image_12 = io.imread("images/good/image12.jpeg")


#single images
print("Type of image is {}".format(image_1.dtype))

skdemo.imshow_with_histogram(image_1[:,:,1])
skdemo.imshow_with_histogram(image_2[:,:,1])
skdemo.imshow_with_histogram(image_3[:,:,1])
skdemo.imshow_with_histogram(image_4[:,:,1])
skdemo.imshow_with_histogram(image_5[:,:,1])
skdemo.imshow_with_histogram(image_6[:,:,1])
skdemo.imshow_with_histogram(image_7[:,:,1])
skdemo.imshow_with_histogram(image_8[:,:,1])
skdemo.imshow_with_histogram(image_9[:,:,1])
skdemo.imshow_with_histogram(image_10[:,:,1])
skdemo.imshow_with_histogram(image_11[:,:,1])
skdemo.imshow_with_histogram(image_12[:,:,1])

# %%
#Cargamos conjunto de naranjas malas
image_13 = io.imread("images/bad/image13.jpeg")
image_14 = io.imread("images/bad/image14.jpeg")
image_15 = io.imread("images/bad/image15.jpeg")
image_16 = io.imread("images/bad/image16.jpeg")
image_17 = io.imread("images/bad/image17.jpeg")
image_18 = io.imread("images/bad/image18.jpeg")
image_19 = io.imread("images/bad/image19.jpeg")
image_20 = io.imread("images/bad/image20.jpeg")
image_21 = io.imread("images/bad/image21.jpeg")
image_22 = io.imread("images/bad/image22.jpeg")
image_23 = io.imread("images/bad/image23.jpeg")

# Visualizamos en el canal verde
skdemo.imshow_with_histogram(image_13[:,:,1])
skdemo.imshow_with_histogram(image_14[:,:,1])
skdemo.imshow_with_histogram(image_15[:,:,1])
skdemo.imshow_with_histogram(image_16[:,:,1])
skdemo.imshow_with_histogram(image_17[:,:,1])
skdemo.imshow_with_histogram(image_18[:,:,1])
skdemo.imshow_with_histogram(image_19[:,:,1])
skdemo.imshow_with_histogram(image_20[:,:,1])
skdemo.imshow_with_histogram(image_21[:,:,1])
skdemo.imshow_with_histogram(image_22[:,:,1])
skdemo.imshow_with_histogram(image_23[:,:,1])

# %%
def transformacion_lineal(img, a):
    b = 0.1
    out = img.copy()
    # Cambiamos la representación de la imagen a real:
    out = skimage.img_as_float64(img)
    
    if a == 1 and b > 0 :
        out = a * out + b
        out = np.clip(out, 0, 1)
    elif a == 1 and b < 0 :
        out = a * out + b
        out = np.clip(out, 0, 1)
    elif  a > 0 and b == 0 :
        out = a * out + b
        out = np.clip(out, 0, 1);
    elif a == 0 and b == 0 :
        out = 1 - out
    else:
        out = img
        
    return out

# %%
brigth_image_enhanced_1 = transformacion_lineal(image_1, 1)
img_ecualizada_ad_1 = exposure.equalize_adapthist(brigth_image_enhanced_1.copy())
ax_image_1, ax_hist_1 = skdemo.imshow_with_histogram(img_ecualizada_ad_1)
skdemo.plot_cdf(img_ecualizada_ad_1, ax=ax_hist_1.twinx())

brigth_image_enhanced_2 = transformacion_lineal(image_2, 1)
img_ecualizada_ad_2 = exposure.equalize_adapthist(brigth_image_enhanced_2.copy())
ax_image_2, ax_hist_2 = skdemo.imshow_with_histogram(img_ecualizada_ad_2)
skdemo.plot_cdf(img_ecualizada_ad_2, ax=ax_hist_2.twinx())

brigth_image_enhanced_3 = transformacion_lineal(image_3, 1)
img_ecualizada_ad_3 = exposure.equalize_adapthist(brigth_image_enhanced_3.copy())
ax_image_3, ax_hist_3 = skdemo.imshow_with_histogram(img_ecualizada_ad_3)
skdemo.plot_cdf(img_ecualizada_ad_3, ax=ax_hist_3.twinx())

brigth_image_enhanced_4 = transformacion_lineal(image_4, 1)
img_ecualizada_ad_4 = exposure.equalize_adapthist(brigth_image_enhanced_4.copy())
ax_image_4, ax_hist_4 = skdemo.imshow_with_histogram(img_ecualizada_ad_4)
skdemo.plot_cdf(img_ecualizada_ad_4, ax=ax_hist_4.twinx())

brigth_image_enhanced_5 = transformacion_lineal(image_5, 1)
img_ecualizada_ad_5 = exposure.equalize_adapthist(brigth_image_enhanced_5.copy())
ax_image_5, ax_hist_5 = skdemo.imshow_with_histogram(img_ecualizada_ad_5)
skdemo.plot_cdf(img_ecualizada_ad_5, ax=ax_hist_5.twinx())

brigth_image_enhanced_6 = transformacion_lineal(image_6, 1)
img_ecualizada_ad_6 = exposure.equalize_adapthist(brigth_image_enhanced_6.copy())
ax_image_6, ax_hist_6 = skdemo.imshow_with_histogram(img_ecualizada_ad_6)
skdemo.plot_cdf(img_ecualizada_ad_6, ax=ax_hist_6.twinx())

brigth_image_enhanced_7 = transformacion_lineal(image_7, 1)
img_ecualizada_ad_7 = exposure.equalize_adapthist(brigth_image_enhanced_7.copy())
ax_image_7, ax_hist_7 = skdemo.imshow_with_histogram(img_ecualizada_ad_7)
skdemo.plot_cdf(img_ecualizada_ad_7, ax=ax_hist_7.twinx())

img_ecualizada_ad_8 = exposure.equalize_adapthist(image_8.copy())
ax_image_8, ax_hist_8 = skdemo.imshow_with_histogram(img_ecualizada_ad_8)
skdemo.plot_cdf(img_ecualizada_ad_8, ax=ax_hist_8.twinx())

img_ecualizada_ad_9 = exposure.equalize_adapthist(image_9.copy())
ax_image_9, ax_hist_9 = skdemo.imshow_with_histogram(img_ecualizada_ad_9)
skdemo.plot_cdf(img_ecualizada_ad_9, ax=ax_hist_9.twinx())

img_ecualizada_ad_10 = exposure.equalize_adapthist(image_10.copy())
ax_image_10, ax_hist_10 = skdemo.imshow_with_histogram(img_ecualizada_ad_10)
skdemo.plot_cdf(img_ecualizada_ad_10, ax=ax_hist_10.twinx())

img_ecualizada_ad_11 = exposure.equalize_adapthist(image_11.copy())
ax_image_11, ax_hist_11 = skdemo.imshow_with_histogram(img_ecualizada_ad_11)
skdemo.plot_cdf(img_ecualizada_ad_11, ax=ax_hist_11.twinx())

img_ecualizada_ad_12 = exposure.equalize_adapthist(image_12.copy())
ax_image_12, ax_hist_12 = skdemo.imshow_with_histogram(img_ecualizada_ad_12)
skdemo.plot_cdf(img_ecualizada_ad_12, ax=ax_hist_12.twinx())

# %%
img_ecualizada_ad_13 = exposure.equalize_adapthist(image_13.copy())
ax_image_13, ax_hist_13 = skdemo.imshow_with_histogram(img_ecualizada_ad_13)
skdemo.plot_cdf(img_ecualizada_ad_13, ax=ax_hist_13.twinx())

img_ecualizada_ad_14 = exposure.equalize_adapthist(image_14.copy())
ax_image_14, ax_hist_14 = skdemo.imshow_with_histogram(img_ecualizada_ad_14)
skdemo.plot_cdf(img_ecualizada_ad_14, ax=ax_hist_14.twinx())

img_ecualizada_ad_15 = exposure.equalize_adapthist(image_15.copy())
ax_image_15, ax_hist_15 = skdemo.imshow_with_histogram(img_ecualizada_ad_15)
skdemo.plot_cdf(img_ecualizada_ad_15, ax=ax_hist_15.twinx())

img_ecualizada_ad_16 = exposure.equalize_adapthist(image_16.copy())
ax_image_16, ax_hist_16 = skdemo.imshow_with_histogram(img_ecualizada_ad_16)
skdemo.plot_cdf(img_ecualizada_ad_16, ax=ax_hist_16.twinx())

img_ecualizada_ad_17 = exposure.equalize_adapthist(image_17.copy())
ax_image_17, ax_hist_17 = skdemo.imshow_with_histogram(img_ecualizada_ad_17)
skdemo.plot_cdf(img_ecualizada_ad_17, ax=ax_hist_17.twinx())

img_ecualizada_ad_18 = exposure.equalize_adapthist(image_18.copy())
ax_image_18, ax_hist_18 = skdemo.imshow_with_histogram(img_ecualizada_ad_18)
skdemo.plot_cdf(img_ecualizada_ad_18, ax=ax_hist_18.twinx())

img_ecualizada_ad_19 = exposure.equalize_adapthist(image_19.copy())
ax_image_19, ax_hist_19 = skdemo.imshow_with_histogram(img_ecualizada_ad_19)
skdemo.plot_cdf(img_ecualizada_ad_19, ax=ax_hist_19.twinx())

img_ecualizada_ad_20 = exposure.equalize_adapthist(image_20.copy())
ax_image_20, ax_hist_20 = skdemo.imshow_with_histogram(img_ecualizada_ad_20)
skdemo.plot_cdf(img_ecualizada_ad_20, ax=ax_hist_20.twinx())

img_ecualizada_ad_21 = exposure.equalize_adapthist(image_21.copy())
ax_image_21, ax_hist_21 = skdemo.imshow_with_histogram(img_ecualizada_ad_21)
skdemo.plot_cdf(img_ecualizada_ad_21, ax=ax_hist_21.twinx())

img_ecualizada_ad_22 = exposure.equalize_adapthist(image_22.copy())
ax_image_22, ax_hist_22 = skdemo.imshow_with_histogram(img_ecualizada_ad_22)
skdemo.plot_cdf(img_ecualizada_ad_22, ax=ax_hist_22.twinx())

img_ecualizada_ad_23 = exposure.equalize_adapthist(image_23.copy())
ax_image_23, ax_hist_23 = skdemo.imshow_with_histogram(img_ecualizada_ad_23)
skdemo.plot_cdf(img_ecualizada_ad_23, ax=ax_hist_23.twinx())

# %%
def metodo_isodata(img):
    
    img_to_gray = color.rgb2gray(img)
    
    t_iso_1 = filters.threshold_isodata(img_to_gray)

    img_BW_iso_1 = img_to_gray > t_iso_1;

    skdemo.imshow_all(img_to_gray, img_BW_iso_1, titles=["Original","umbral isodata"])
    
    return img_BW_iso_1

# %%
img_iso_1 = metodo_isodata(img_ecualizada_ad_1)
img_iso_2 = metodo_isodata(img_ecualizada_ad_2)
img_iso_3 = metodo_isodata(img_ecualizada_ad_3)
img_iso_4 = metodo_isodata(img_ecualizada_ad_4)
img_iso_5 = metodo_isodata(img_ecualizada_ad_5)
img_iso_6 = metodo_isodata(img_ecualizada_ad_6)
img_iso_7 = metodo_isodata(img_ecualizada_ad_7)
img_iso_8 = metodo_isodata(img_ecualizada_ad_8)
img_iso_9 = metodo_isodata(img_ecualizada_ad_9)
img_iso_10 = metodo_isodata(img_ecualizada_ad_10)
img_iso_11 = metodo_isodata(img_ecualizada_ad_11)
img_iso_12 = metodo_isodata(img_ecualizada_ad_12)

# %%
img_iso_13 = metodo_isodata(img_ecualizada_ad_13)
img_iso_14 = metodo_isodata(img_ecualizada_ad_14)
img_iso_15 = metodo_isodata(img_ecualizada_ad_15)
img_iso_16 = metodo_isodata(img_ecualizada_ad_16)
img_iso_17 = metodo_isodata(img_ecualizada_ad_17)
img_iso_18 = metodo_isodata(img_ecualizada_ad_18)
img_iso_19 = metodo_isodata(img_ecualizada_ad_19)
img_iso_20 = metodo_isodata(img_ecualizada_ad_20)
img_iso_21 = metodo_isodata(img_ecualizada_ad_21)
img_iso_22 = metodo_isodata(img_ecualizada_ad_22)
img_iso_23 = metodo_isodata(img_ecualizada_ad_23)

# %%
print(img_iso_10)

# %%
good_orange_1 = img_iso_1.astype("uint8")
good_orange_2 = img_iso_2.astype("uint8")
good_orange_3 = img_iso_3.astype("uint8")
good_orange_4 = img_iso_4.astype("uint8")
good_orange_5 = img_iso_5.astype("uint8")
good_orange_6 = img_iso_6.astype("uint8")
good_orange_7 = img_iso_7.astype("uint8")
good_orange_8 = img_iso_8.astype("uint8")
good_orange_9 = img_iso_9.astype("uint8")
good_orange_10 = img_iso_10.astype("uint8")
good_orange_11 = img_iso_11.astype("uint8")
good_orange_12 = img_iso_12.astype("uint8")

# %%
bad_orange_13 = img_iso_13.astype("uint8")
bad_orange_14 = img_iso_14.astype("uint8")
bad_orange_15 = img_iso_15.astype("uint8")
bad_orange_16 = img_iso_16.astype("uint8")
bad_orange_17 = img_iso_17.astype("uint8")
bad_orange_18 = img_iso_18.astype("uint8")
bad_orange_19 = img_iso_19.astype("uint8")
bad_orange_20 = img_iso_20.astype("uint8")
bad_orange_21 = img_iso_21.astype("uint8")
bad_orange_22 = img_iso_22.astype("uint8")
bad_orange_23 = img_iso_23.astype("uint8")

# %%
f1 = measure.label(good_orange_1) 
f2 = measure.label(good_orange_2) 
f3 = measure.label(good_orange_3) 
f4 = measure.label(good_orange_4) 
f5 = measure.label(good_orange_5) 
f6 = measure.label(good_orange_6) 
f7 = measure.label(good_orange_7) 
f8 = measure.label(good_orange_8) 
f9 = measure.label(good_orange_9) 
f10 = measure.label(good_orange_10) 
f11 = measure.label(good_orange_11) 
f12 = measure.label(good_orange_12)

skdemo.imshow_all(f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, f11, f12, cmap="jet");

# %%
f13 = measure.label(bad_orange_13) 
f14 = measure.label(bad_orange_14) 
f15 = measure.label(bad_orange_15) 
f16 = measure.label(bad_orange_16) 
f17 = measure.label(bad_orange_17) 
f18 = measure.label(bad_orange_18) 
f19 = measure.label(bad_orange_19) 
f20 = measure.label(bad_orange_20) 
f21 = measure.label(bad_orange_21) 
f22 = measure.label(bad_orange_22)
f23 = measure.label(bad_orange_23)

skdemo.imshow_all(f13, f14, f15, f16, f17, f18, f19, f20, f21, f22, f23, cmap="jet");

# %%
y1 = np.full((f1.max(),1), 1) #Naranjas buenas
y2 = np.full((f2.max(),1), 1) #Naranjas buenas
y3 = np.full((f3.max(),1), 1) #Naranjas buenas
y4 = np.full((f4.max(),1), 1) #Naranjas buenas
y5 = np.full((f5.max(),1), 1) #Naranjas buenas
y6 = np.full((f6.max(),1), 1) #Naranjas buenas
y7 = np.full((f7.max(),1), 1) #Naranjas buenas
y8 = np.full((f8.max(),1), 1) #Naranjas buenas
y9 = np.full((f9.max(),1), 1) #Naranjas buenas
y10 = np.full((f10.max(),1), 1) #Naranjas buenas
y11 = np.full((f11.max(),1), 1) #Naranjas buenas
y12 = np.full((f12.max(),1), 1) #Naranjas buenas

# %%
y13 = np.full((f13.max(),1), 2) #Naranjas malas
y14 = np.full((f14.max(),1), 2) #Naranjas malas
y15 = np.full((f15.max(),1), 2) #Naranjas malas
y16 = np.full((f16.max(),1), 2) #Naranjas malas
y17 = np.full((f17.max(),1), 2) #Naranjas malas
y18 = np.full((f18.max(),1), 2) #Naranjas malas
y19 = np.full((f19.max(),1), 2) #Naranjas malas
y20 = np.full((f20.max(),1), 2) #Naranjas malas
y21 = np.full((f21.max(),1), 2) #Naranjas malas
y22 = np.full((f22.max(),1), 2) #Naranjas malas
y23 = np.full((f23.max(),1), 2) #Naranjas malas

# %%
y = np.vstack([y1,y2,y3,y4,y5,y6,y7,y8,y9,y10,y11,y12,y13,y14,y15,y16,y17,y18,y19,y20,y21,y22,y23])
y = np.ravel(y)

# %%
props_f1 = measure.regionprops(f1, coordinates='rc')
props_f2 = measure.regionprops(f2, coordinates='rc')
props_f3 = measure.regionprops(f3, coordinates='rc')
props_f4 = measure.regionprops(f4, coordinates='rc')
props_f5 = measure.regionprops(f5, coordinates='rc')
props_f6 = measure.regionprops(f6, coordinates='rc')
props_f7 = measure.regionprops(f7, coordinates='rc')
props_f8 = measure.regionprops(f8, coordinates='rc')
props_f9 = measure.regionprops(f9, coordinates='rc')
props_f10 = measure.regionprops(f10, coordinates='rc')
props_f11 = measure.regionprops(f11, coordinates='rc')
props_f12 = measure.regionprops(f12, coordinates='rc')

# %%
props_f13 = measure.regionprops(f13, coordinates='rc')
props_f14 = measure.regionprops(f14, coordinates='rc')
props_f15 = measure.regionprops(f15, coordinates='rc')
props_f16 = measure.regionprops(f16, coordinates='rc')
props_f17 = measure.regionprops(f17, coordinates='rc')
props_f18 = measure.regionprops(f18, coordinates='rc')
props_f19 = measure.regionprops(f19, coordinates='rc')
props_f20 = measure.regionprops(f20, coordinates='rc')
props_f21 = measure.regionprops(f21, coordinates='rc')
props_f22 = measure.regionprops(f22, coordinates='rc')
props_f23 = measure.regionprops(f23, coordinates='rc')

# %%
from itertools import chain # Solo lo usamos para juntar los tres iterables en uno
y_iter = chain(props_f1, 
               props_f2, 
               props_f3, 
               props_f4, 
               props_f5, 
               props_f6, 
               props_f7, 
               props_f8, 
               props_f9,
               props_f10, 
               props_f11, 
               props_f12, 
               props_f13, 
               props_f14, 
               props_f15, 
               props_f16, 
               props_f17, 
               props_f18,
               props_f19, 
               props_f20, 
               props_f21, 
               props_f22, 
               props_f23)

# %%
Xn = np.array(["Area",
              "Perimetro",
              "Solidez", 
              "Excentricidad", 
              "Centroide X",
              "Centroide Y",
              "Diametro Equiv", 
              "Eje Mayor", 
              "Eje Menor", 
              "m1",
              "m2",
              "m3",
              "m4",
              "m5",
              "m6",
              "m7"
              ])

# Creamos la matriz de datos vacía
X = None

# Recorremos cada objeto y vamos concatenando las características de estos
for obj in y_iter:
    X_obj = np.array([
                obj.area,
                obj.perimeter,
                obj.solidity,        
                obj.eccentricity,
                obj.centroid[0],
                obj.centroid[1],
                obj.equivalent_diameter,
                obj.major_axis_length,
                obj.minor_axis_length,
                obj.moments_hu[0],
                obj.moments_hu[1],
                obj.moments_hu[2],
                obj.moments_hu[3],
                obj.moments_hu[4],
                obj.moments_hu[5],
                obj.moments_hu[6]
    ])
    
    #Agregamos las características del objeto a la matriz X
    if X is None:
        X = X_obj.copy()
    else:
        X = np.vstack((X, X_obj))

# %%
#Se aplica la función para escalar los datos
scaler = preprocessing.MinMaxScaler()
X_scl = scaler.fit_transform(X)

# %%
#Creamos el selector de características para eliminar las irrelevantes
selector = feature_selection.VarianceThreshold()

# Creamos la nueva matriz de características
X_new1 = selector.fit_transform(X_scl)

# %%
#No pudimos superar este error: Found input variables with inconsistent numbers of samples: [63840, 23]
# https://github.com/scikit-multilearn/scikit-multilearn/issues/118
# https://github.com/scikit-learn/scikit-learn/issues/8908



#SELECCION DE CARACTERISTICAS INDIVIDUAL
# Recuerde que las etiquetas de clase de las flechas las tenemos en un arreglo llamado y
print ("Etiquetas de los datos:\n", y)

# Calculamos el criterio de información mutua
mi = feature_selection.mutual_info_classif(X_scl, y)

# Visualizamos el valor de la métrica usando un gráfico de puntos
plt.figure(figsize=(6,4))
plt.plot(mi, 'o-')


#SELECCION RECURSIVA DE CARACTERISTICAS
# En este caso, la métrica de selección es la precisión de clasificación usando una SVM lineal
# Creamos el clasificador
svc = svm.SVC(kernel="linear", C=1)

# Definimos el método de selección indicando que vamos a seleccionar 5 características
rfe = feature_selection.RFE(estimator=svc, n_features_to_select=5, step=1)

#Creamos la nueva matriz de características
X_new2 = rfe.fit_transform(X_scl, y)

# Visualizamos como quedaron organizadas las características.
# Aquellas con valor 1 son las seleccionadas
print ("Ranking de Caracteríticas: ", rfe.ranking_)

# Características seleccionadas
idx = rfe.get_support(indices=True)

#Filtramos los nombres de las nuevas características
Xn_new2 = Xn[idx]

#¿Qué características nos quedan?
print("Características seleccionadas por selección hacia atrás:", Xn_new2)
